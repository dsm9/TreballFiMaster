# %% [markdown]
# # Language problem
# Spacy doesn't detect correctly the language in some cases, despite they are current sentencies in spanish or catalan.

# %%
import json
import os.path
import sys
import csv
import numpy as np
import pandas as pd
from colorama import Fore

# %%
import spacy
from spacy_langdetect import LanguageDetector

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("es_core_news_sm")

nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)

# %%
pathori = "../data/original"
pathdest = "../data/preprocessed/"
debug = True

# %%
# Loading file of languages other than es, ca, en
file = "comentaris_xx.csv"
data = pd.read_csv(pathdest + file)
display (data)
# Out:
#        Curs TipusPregunta                      TipusIncidencia  \
# 0   2017-18             P  No ha impartit classe a aquest grup
# 1   2017-18             P  No ha impartit classe a aquest grup
# 2   2017-18             P  No ha impartit classe a aquest grup
# 3   2017-18             A                                  NaN
# 4   2017-18             P                                  NaN
# ..      ...           ...                                  ...
# 80  2019-20             P  No ha impartit classe a aquest grup
# 81  2019-20             A                                  NaN
# 82  2019-20             P                                  NaN
# 83  2019-20             P                                  NaN
# 84  2019-20             P  No ha impartit classe a aquest grup
#
#                                             Comentari Idioma
# 0                                No he tratado con él     pt
# 1                                No he tratado con él     pt
# ...

# %%
#   Distribution by Idioma        
data_group = data[["Idioma","Comentari"]].groupby(["Idioma"]).count()
if debug:
    display (data_group)
# Out:
#          Comentari
# Idioma
# UNKNOWN          4
# af               1
# de               4
# et               1
# fr              14
# hu               1
# id               2
# it              15
# lt               1
# nl               5
# no               3
# pt              21
# ro               4
# sl               1
# so               2
# sq               1
# sv               2
# sw               3

# %%
# Sentences example
data_group = data[["Comentari", "Idioma", "Curs"]].groupby(["Comentari", "Idioma"]).count().sort_values(["Comentari"])
#data_group = data[["Comentari", "Idioma"]].value_counts()
if debug:
    display (data_group.head(20))
# Out:
#                                                             Curs
# Comentari                                          Idioma
# \r\n                                               UNKNOWN     2
# 0                                                  UNKNOWN     1
# <3 a Haskell                                       no          1
# AMB AQUESTA ASSIGNATURA S'HA POGUT OBTINDRE UNA... de          1
# Assignatura importantíssima.                       pt          1
# Assignatura molt interessant                       it          1
# Assignatura molt interessant.                      it          1
# Assignatura que podria ser útil pero que amb la... pt          1
# Ben fet, m'ha agradat.                             sv          1
# Bona gent                                          nl          1
# Bé.                                                fr          1
# Classes avorrides.                                 fr          1
# Comença les classes a les 16.10h en compte de l... fr          2
# ...
