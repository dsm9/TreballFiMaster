# %% [markdown]
# # Language detection: Spacy vs Pycld2
#
# This notebook will compare the language detection between Spacy and Pycld2

# %%
import pandas as pd
from colorama import Fore

# %%
import spacy
from spacy_langdetect import LanguageDetector

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")
# ca_fasttext_wiki
# es_core_news_sm
# en_core_web_sm

nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)

# %%
import pycld2 as cld2

# %%
pathori = "../data/original"
pathdest = "../data/preprocessed/"
pathmodel = "../data/models/"
debug = 1

# %%
def load_data():
    languages = {"ca":"ca_fasttext_wiki", "es":"es_core_news_sm", 
                 "en":"en_core_web_sm", "xx":"" }

    data_total = pd.DataFrame(columns=["Comentari","TipusIncidencia","Idioma"])

    for language in languages:
        model = languages[language]
        file = "comentaris_" + language + ".csv"
        if (debug >= 1):
            print ("language: ", language)
            print ("model: ", model)
            print ("file:", file)

        # Load data from file

        data_csv = pd.read_csv(pathdest + file)
        data_lang = data_csv[["Comentari","TipusIncidencia","IdiomaSpacy","IdiomaPyCld2","Idioma"]]
        if (debug >= 2):
            display (data_lang.sample(5))
        if (debug >= 1):
            print ("rows:", data_lang.shape[0])
            print ("")

        data_total = pd.concat([data_total, data_lang])
        
    data_total = data_total[data_total["Comentari"].notnull()]
    data_total = data_total.reset_index()
    if (debug >= 1):
        print ("data_total: ", data_total.shape[0], " rows")

    if (debug >= 2):
        display (data_total.sample(5))
        
    return data_total

# %%
data = load_data()
if (debug >= 1):
    display(data)
# Out:
# language:  ca
# model:  ca_fasttext_wiki
# file: comentaris_ca.csv
# rows: 6199
#
# language:  es
# model:  es_core_news_sm
# file: comentaris_es.csv
# rows: 1370
#
# language:  en
# model:  en_core_web_sm
# file: comentaris_en.csv
# rows: 232
#
# language:  xx
# model:
# file: comentaris_xx.csv
# rows: 91
#
# data_total:  7892  rows
#       index                                          Comentari  \
# 0         0  Els continguts d'aquesta assignatura ja els ha...
# 1         1  L'actitud de la professora em resulta molt mot...
# 2         2  Materials molt interessants i bones orientacio...
# 3         3  Ha estat una exigència molt forta de treball: ...
# 4         4  Molta satisfacció amb la transparència i l'ant...
# ...     ...                                                ...
# 7887     86                                  No he après res.
# 7888     87                                   POC PROFESSIONAL
# 7889     88                        Un exemple de bon professor
# 7890     89                                          PROFE TOP
# 7891     90                         No he demanat cap tutoria.
#
#      TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 0                NaN     ca          ca           ca
# 1                NaN     ca          ca           pt
# 2                NaN     ca          ca           ca
# 3                NaN     ca          ca           ca
# 4                NaN     ca          ca           ca
# ...              ...    ...         ...          ...
# 7887             NaN     fr          fr           fr
# 7888             NaN     pl          pl           ie
# 7889             NaN     fr          fr           en
# 7890             NaN     vi          vi           en
# 7891             NaN     it          it           en
#
# [7892 rows x 6 columns]

# %%
#   Distribution by Idioma        
data_group = data[["IdiomaSpacy","Comentari"]].groupby(["IdiomaSpacy"]).count()
if debug:
    print ("Idioma Spacy:")
    display (data_group.sort_values("Comentari", ascending=False).head(10))
# Out:
# Idioma Spacy:
#              Comentari
# IdiomaSpacy
# ca                6020
# es                1354
# en                 322
# fr                  43
# it                  41
# pt                  37
# de                  11
# UNKNOWN             10
# nl                   8
# hu                   6

# %%
#   Distribution by IdiomaPycld2        
data_group = data[["IdiomaPyCld2","Comentari"]].groupby(["IdiomaPyCld2"]).count()
if debug:
    print ("Idioma Pycld2:")
    display (data_group.sort_values("Comentari", ascending=False).head(10))
# Out:
# Idioma Pycld2:
#               Comentari
# IdiomaPyCld2
# ca                 5982
# es                 1347
# en                  428
# fy                   25
# tk                   14
# un                   13
# hu                   13
# oc                    8
# pt                    7
# gl                    6

# %%
#   Comparativa idiomas        
data_group = data[["IdiomaSpacy","IdiomaPyCld2","Comentari"]].groupby(["IdiomaSpacy","IdiomaPyCld2"]).count().reset_index()
display (data_group.sort_values("Comentari", ascending=False).head(10))
data_pivot = data_group.pivot(index="IdiomaSpacy", columns="IdiomaPyCld2", values="Comentari")
if debug:
    display (data_pivot)
# Out:
#    IdiomaSpacy IdiomaPyCld2  Comentari
# 3           ca           ca       5839
# 34          es           es       1300
# 25          en           en        232
# 5           ca           en        140
# 24          en           ca         57
# 53          it           ca         24
# 31          es           ca         20
# 33          es           en         20
# 74          pt           es         19
# 41          fr           ca         16
# IdiomaPyCld2   af      ca  crs   cs   cy   de     en      es   fi   fr  ...  \
# IdiomaSpacy                                                             ...
# UNKNOWN       NaN     NaN  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# af            1.0     1.0  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# ca            NaN  5839.0  NaN  NaN  NaN  1.0  140.0    11.0  NaN  1.0  ...
# de            NaN     4.0  NaN  NaN  NaN  NaN    2.0     4.0  NaN  NaN  ...
# en            1.0    57.0  NaN  NaN  NaN  NaN  232.0     7.0  NaN  NaN  ...
# es            NaN    20.0  NaN  1.0  NaN  NaN   20.0  1300.0  NaN  NaN  ...
# fr            NaN    16.0  NaN  NaN  NaN  NaN   12.0     3.0  NaN  3.0  ...
# hr            NaN     NaN  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# hu            NaN     6.0  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# id            NaN     2.0  NaN  NaN  NaN  NaN    1.0     NaN  NaN  NaN  ...
# it            NaN    24.0  1.0  NaN  NaN  NaN    4.0     2.0  NaN  NaN  ...
# lt            NaN     NaN  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# nl            NaN     3.0  NaN  NaN  NaN  NaN    3.0     NaN  NaN  NaN  ...
# no            NaN     NaN  NaN  NaN  NaN  NaN    2.0     NaN  1.0  NaN  ...
# pl            NaN     NaN  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# pt            NaN     5.0  NaN  2.0  1.0  NaN    6.0    19.0  1.0  NaN  ...
# ro            NaN     1.0  NaN  NaN  NaN  NaN    2.0     NaN  NaN  NaN  ...
# sl            NaN     1.0  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# so            NaN     NaN  NaN  NaN  NaN  NaN    1.0     NaN  NaN  NaN  ...
# sv            NaN     2.0  NaN  NaN  NaN  NaN    NaN     NaN  NaN  NaN  ...
# sw            NaN     NaN  NaN  NaN  NaN  NaN    2.0     1.0  NaN  NaN  ...
# vi            NaN     1.0  NaN  NaN  NaN  NaN    1.0     NaN  NaN  NaN  ...
#
# IdiomaPyCld2   lb   ms   oc   pt   sk    tk   tn    un   xh   yo
# IdiomaSpacy
# UNKNOWN       NaN  NaN  NaN  NaN  NaN   NaN  NaN  10.0  NaN  NaN
# af            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# ca            1.0  1.0  3.0  6.0  1.0   NaN  NaN   2.0  NaN  1.0
# de            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# en            NaN  NaN  1.0  NaN  NaN  12.0  NaN   NaN  NaN  NaN
# es            NaN  NaN  2.0  1.0  1.0   NaN  NaN   NaN  NaN  NaN
# fr            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  5.0
# hr            NaN  NaN  1.0  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# hu            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# id            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# it            NaN  NaN  1.0  NaN  NaN   NaN  1.0   NaN  NaN  NaN
# lt            NaN  NaN  NaN  NaN  NaN   NaN  NaN   1.0  NaN  NaN
# nl            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# no            NaN  NaN  NaN  NaN  NaN   1.0  NaN   NaN  NaN  NaN
# pl            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# pt            NaN  NaN  NaN  NaN  NaN   1.0  NaN   NaN  NaN  NaN
# ro            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# sl            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# so            NaN  1.0  NaN  NaN  NaN   NaN  NaN   NaN  1.0  NaN
# sv            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# sw            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
# vi            NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN
#
# [22 rows x 28 columns]

# %%
data_dif = data[data["IdiomaSpacy"] != data["IdiomaPyCld2"]]
display (data_dif)
print (data_dif.shape[0])
# Out:
#       index                                          Comentari  \
# 1         1  L'actitud de la professora em resulta molt mot...
# 9         9                                      Gran profesor
# 35       35                                    No l'hem tingut
# 38       38                                     no l´he tingut
# 40       40                    No he tingut aquesta professora
# ...     ...                                                ...
# 7886     85                                               \r\n
# 7888     87                                   POC PROFESSIONAL
# 7889     88                        Un exemple de bon professor
# 7890     89                                          PROFE TOP
# 7891     90                         No he demanat cap tutoria.
#
#                           TipusIncidencia   Idioma IdiomaSpacy IdiomaPyCld2
# 1                                     NaN       ca          ca           pt
# 9                                     NaN       ca          en           fy
# 35    No ha impartit classe a aquest grup       ca          en           tk
# 38    No ha impartit classe a aquest grup       ca          en           ca
# 40    No ha impartit classe a aquest grup       ca          en           ca
# ...                                   ...      ...         ...          ...
# 7886                                  NaN  UNKNOWN     UNKNOWN           un
# 7888                                  NaN       pl          pl           ie
# 7889                                  NaN       fr          fr           en
# 7890                                  NaN       vi          vi           en
# 7891                                  NaN       it          it           en
#
# [517 rows x 6 columns]
# 517

# %%
data_dif = data[(data["IdiomaSpacy"] == "ca") & (data["IdiomaPyCld2"] == "en")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 85       85                         Gemma Filella és una crak
# 90       90  Gemma Filella és una peça imprescindible per a...
# 183     183  Algunes classes eren més dinàmiques que altres...
# 242     242                 Bon professor tècnicament parlant.
# 244     244                             Ha estat entretingut.
# ...     ...                                                ...
# 6031   6031  Es inacceptable que una professora exigeigi pu...
# 6071   6071  Bona assignatura, útil, flexiblible i s'ha ada...
# 6078   6078  Fan falta més professors com ell,que disfrutin...
# 6095   6095                                Res a dir. Perfecte
# 6111   6111  Bon professor, comprensiu, atent i es sap adap...
#
#            TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 85    Comentari excel·lent     ca          ca           en
# 90                     NaN     ca          ca           en
# 183                    NaN     ca          ca           en
# 242                    NaN     ca          ca           en
# 244                    NaN     ca          ca           en
# ...                    ...    ...         ...          ...
# 6031                   NaN     ca          ca           en
# 6071                   NaN     ca          ca           en
# 6078                   NaN     ca          ca           en
# 6095                   NaN     ca          ca           en
# 6111                   NaN     ca          ca           en
#
# [140 rows x 6 columns]
# 140  rows

# %%
data_dif = data[(data["IdiomaSpacy"] == "ca") & (data["IdiomaPyCld2"] != "ca") & (data["IdiomaPyCld2"] != "es") & (data["IdiomaPyCld2"] != "en")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 1         1  L'actitud de la professora em resulta molt mot...
# 58       58                              M'ha sembla correcta.
# 68       68                          Falten exercicis per fer.
# 77       77                                  És un incompetent
# 121     121             Per venir a vendre la empresa només...
# 219     219  Teoria rapida i temps de practica a classe. Co...
# 273     273                         És un professor correcte.
# 400     400   No puc evaluar-lo, no estava quan va fer classe.
# 402     402     Sempre disposat a ajudar en el que necessitis.
# 438     438                                     És una crack!!
# 560     560                               Classe massa teòrica
# 698     698                  Un expert i crack en la matèria!
# 729     729                         Manera d'explicar pessada.
# 841     841                                    No s'explica bé
# 975     975  Molt content en com sha portat lassignatura de...
# 1261   1261  Alguns cops penso que faltava preparació prèvi...
# 1579   1579  El funcionament del primer parcial durant la q...
# 1757   1757                     És una excel·lent professora.
# 1808   1808                            És una gran professora.
# 1883   1883  NO val per res, nomes pensa en putejar el pers...
# 2208   2208                              És una professora 10.
# 2774   2774  No fica examen del teoria i fica coses que no ...
# 3145   3145                             Es una Bona professora
# 3426   3426  L'Enric ha estat un professor que s'ha adaptat...
# 5004   5004                     És un 10 de professora!!!!!!!!
# 5322   5322                            És una bona professora.
# 5401   5401                        És una docent exemplar.\r\n
# 6063   6063                                       No se qui és
# 6094   6094                                  Res a dir. Genial
# 6120   6120                       Un 10 de persona i professor
#
#                           TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 1                                     NaN     ca          ca           pt
# 58                                    NaN     ca          ca           ie
# 68                                    NaN     ca          ca           de
# 77                                    NaN     ca          ca           hu
# 121                                   NaN     ca          ca           fr
# 219                                   NaN     ca          ca           un
# 273                                   NaN     ca          ca           hu
# 400                                   NaN     ca          ca           pt
# 402                                   NaN     ca          ca           pt
# 438                                   NaN     ca          ca           hu
# 560                                   NaN     ca          ca           un
# 698                                   NaN     ca          ca           oc
# 729                                   NaN     ca          ca           pt
# 841                                   NaN     ca          ca           yo
# 975                                   NaN     ca          ca           sk
# 1261                                  NaN     ca          ca           pt
# 1579                                  NaN     ca          ca           oc
# 1757                                  NaN     ca          ca           hu
# 1808                                  NaN     ca          ca           hu
# 1883                    Comentari ofensiu     ca          ca           ms
# 2208                                  NaN     ca          ca           hu
# 2774                                  NaN     ca          ca           pt
# 3145                                  NaN     ca          ca           fy
# 3426                                  NaN     ca          ca           oc
# 5004                                  NaN     ca          ca           hu
# 5322                                  NaN     ca          ca           hu
# 5401                                  NaN     ca          ca           jw
# 6063  No ha impartit classe a aquest grup     ca          ca           hu
# 6094                                  NaN     ca          ca           lb
# 6120                                  NaN     ca          ca           fy
# 30  rows

# %%
data_dif = data[(data["IdiomaSpacy"] == "es") & (data["IdiomaPyCld2"] == "en")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 6226     27    En los videos tutoriales no hablar tan deprisa.
# 6261     62             comprensible, entendor, bon professor.
# 6281     82  las diapositivas deberian ser en castellano y ...
# 6288     89  Parts poc interrelacionades, sense fil conduct...
# 6349    150  Profesora creativa y intelectual de todo signi...
# 6477    278                                        Un maestro!
# 6502    303                       - Muy disponible y atento.\n
# 6510    311  Se echan en falta temarios en audio o audiovis...
# 6565    366                        Su entusiamo es envidiable.
# 6716    517  Se agradece su entusiasmo y actitud a la hora ...
# 6731    532  Que de la clase la profesora en lugar de envia...
# 6785    586  Se ha adaptado correctamente a las circunstanc...
# 6791    592  El profesor que mejor se ha adaptado a la univ...
# 6924    725                No s'enten res del que vol explicar
# 7023    824                                          Perfecta.
# 7027    828                                          Correcte.
# 7056    857  Casos prácticos a estudiar, explicar los power...
# 7178    979  Sinceramente, ha sido una vergüenza de asignatura
# 7380   1181                    interesante temario, buen profe
# 7419   1220                               Add videoconferences
#
#      TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 6226             NaN     es          es           en
# 6261             NaN     es          es           en
# 6281             NaN     es          es           en
# 6288             NaN     es          es           en
# 6349             NaN     es          es           en
# 6477             NaN     es          es           en
# 6502             NaN     es          es           en
# 6510             NaN     es          es           en
# 6565             NaN     es          es           en
# 6716             NaN     es          es           en
# 6731             NaN     es          es           en
# 6785             NaN     es          es           en
# 6791             NaN     es          es           en
# 6924             NaN     es          es           en
# 7023             NaN     es          es           en
# 7027             NaN     es          es           en
# 7056             NaN     es          es           en
# 7178             NaN     es          es           en
# 7380             NaN     es          es           en
# 7419             NaN     es          es           en
# 20  rows

# %%
data_dif = data[(data["IdiomaSpacy"] == "es") & (data["IdiomaPyCld2"] != "es") & (data["IdiomaPyCld2"] != "ca") 
                & (data["IdiomaPyCld2"] != "en")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 6223     24    Materiales estupendos para disfrutar y aprender
# 6286     87                              No em crida l'atenció
# 6335    136                                 Excelente docente.
# 6377    178                No vimos a en clase a este docente
# 6394    195                               Excelente profesor.
# 6470    271                              No vimos clase con él
# 6471    272                            No vimos clase con ella
# 6547    348              Excelente para la formación de Master
# 6557    358                 mala organización de la asignatura
# 6621    422     Los testes de teoria son tediosos y dificiles.
# 6818    619     De dificil acceso y ausente durante el curso.
# 7222   1023  Pese a que esta asignatura debe de ser presenc...
# 7336   1137  Los métodos utilizados por Ines son los adecua...
# 7409   1210            Trobo que no esta gaire ben plantejada
#
#                           TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 6223                                  NaN     es          es           id
# 6286                                  NaN     es          es           pt
# 6335                                  NaN     es          es           cs
# 6377                                  NaN     es          es           gl
# 6394                                  NaN     es          es           fy
# 6470  No ha impartit classe a aquest grup     es          es           gl
# 6471  No ha impartit classe a aquest grup     es          es           gl
# 6547                                  NaN     es          es           gl
# 6557                                  NaN     es          es           sk
# 6621                                  NaN     es          es           oc
# 6818                                  NaN     es          es           gl
# 7222                                  NaN     es          es           gl
# 7336                                  NaN     es          es           id
# 7409                                  NaN     es          es           oc
# 14  rows

# %%
data_dif = data[(data["IdiomaSpacy"] == "en") & (data["IdiomaPyCld2"] == "es")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 6247     48  AL PINCIPIO DESCORDINACIÓN DE LA ASIGNATURA , ...
# 6351    152                                Un buen profesional
# 6658    459                                Muy buen profesor!!
# 6782    583                                    Muy buen profe!
# 7016    817  ME HA GUSTADO MUCHO LA PROFESORA, SOBRE TODO, ...
# 7022    823  BUEN PROFESOR...HA DESPERTADO INTERÉS EN LA AS...
# 7386   1187  NO HA FACILITADO NADA LA SITUACIÓN ACTUAL CON ...
#
#      TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 6247             NaN     es          en           es
# 6351             NaN     es          en           es
# 6658             NaN     es          en           es
# 6782             NaN     es          en           es
# 7016             NaN     es          en           es
# 7022             NaN     es          en           es
# 7386             NaN     es          en           es
# 7  rows

# %%
data_dif = data[(data["IdiomaSpacy"] == "en") & (data["IdiomaPyCld2"] != "en") & (data["IdiomaPyCld2"] != "ca")
                & (data["IdiomaPyCld2"] != "es")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                            Comentari  \
# 9         9                        Gran profesor
# 35       35                      No l'hem tingut
# 82       82                      No l’hem tingut
# 95       95                      No l'hem tingut
# 99       99                      No l’hem tingut
# 128     128              És mlt bon professor ;)
# 359     359                      No l'hem tingut
# 378     378                      No l’hem tingut
# 444     444                      No l’hem tingut
# 771     771                     No l'hem tingut.
# 879     879                      No l'hem tingut
# 947     947                      No l'hem tingut
# 1220   1220  Professor molt útil, bon professor.
# 1518   1518                     No l’hem tingut.
# 1834   1834                       Bon profesor.
# 1837   1837                   Un bon professor.
# 2347   2347     No l’hem tingut a fisiologia II.
# 2847   2847                   Professorat inepte
# 3013   3013                          Bona profe.
# 3859   3859                   Un bon professor.
# 4492   4492                       Bon professor.
# 4931   4931                       Gran profesor.
# 5085   5085                        Bon professor
# 5135   5135                        Bon professor
# 5821   5821             Tot lo dit anteriorment.
# 5883   5883             ´Metòdic i bon professor
#
#                           TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 9                                     NaN     ca          en           fy
# 35    No ha impartit classe a aquest grup     ca          en           tk
# 82    No ha impartit classe a aquest grup     ca          en           tk
# 95    No ha impartit classe a aquest grup     ca          en           tk
# 99    No ha impartit classe a aquest grup     ca          en           tk
# 128                                   NaN     ca          en           hu
# 359   No ha impartit classe a aquest grup     ca          en           tk
# 378                                   NaN     ca          en           tk
# 444                                   NaN     ca          en           tk
# 771   No ha impartit classe a aquest grup     ca          en           tk
# 879   No ha impartit classe a aquest grup     ca          en           tk
# 947   No ha impartit classe a aquest grup     ca          en           tk
# 1220                                  NaN     ca          en           fy
# 1518  No ha impartit classe a aquest grup     ca          en           tk
# 1834                                  NaN     ca          en           fy
# 1837                                  NaN     ca          en           fy
# 2347  No ha impartit classe a aquest grup     ca          en           tk
# 2847                                  NaN     ca          en           fy
# 3013                                  NaN     ca          en           fy
# 3859                                  NaN     ca          en           fy
# 4492                                  NaN     ca          en           fy
# 4931                                  NaN     ca          en           fy
# 5085                                  NaN     ca          en           fy
# 5135                                  NaN     ca          en           fy
# 5821                                  NaN     ca          en           af
# 5883                                  NaN     ca          en           oc
# 26  rows

# %%
data_dif = data[(data["IdiomaSpacy"] != "ca") & (data["IdiomaSpacy"] != "es") & (data["IdiomaSpacy"] != "en")
                & (data["IdiomaPyCld2"] == "ca")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 129     129       No ens expliqueu coses que no ens interessen
# 140     140  AMB AQUESTA ASSIGNATURA S'HA POGUT OBTINDRE UN...
# 203     203                                         Bona gent
# 204     204                                     Molt bona gent
# 243     243                             Ben fet, m'ha agradat.
# ...     ...                                                ...
# 5595   5595                                 Molt comprensiva.
# 5622   5622                      Assignatura molt interessant!
# 5877   5877            REMARCAR LA VOCACIÓ DELS DOS PROFESSORS
# 6008   6008  Les professores a vegades et diuen coses contr...
# 6020   6020                                  Sense paraules...
#
#      TipusIncidencia Idioma IdiomaSpacy IdiomaPyCld2
# 129              NaN     ca          fr           ca
# 140              NaN     ca          de           ca
# 203              NaN     ca          nl           ca
# 204              NaN     ca          nl           ca
# 243              NaN     ca          sv           ca
# ...              ...    ...         ...          ...
# 5595             NaN     ca          it           ca
# 5622             NaN     ca          it           ca
# 5877             NaN     ca          de           ca
# 6008             NaN     ca          fr           ca
# 6020             NaN     ca          fr           ca
#
# [66 rows x 6 columns]
# 66  rows

# %%
data_dif = data[(data["IdiomaSpacy"] != "ca") & (data["IdiomaSpacy"] != "es") & (data["IdiomaSpacy"] != "en")
                & (data["IdiomaPyCld2"] != "ca") & (data["IdiomaPyCld2"] != "es") & (data["IdiomaPyCld2"] != "en")]
display (data_dif)
print (data_dif.shape[0], " rows")
# Out:
#       index                                          Comentari  \
# 1230   1230  Quan he tingut algun problema o dubte m'ha int...
# 1231   1231                                                 ca
# 2373   2373  Molts cops fa comentaris que estan fora de llo...
# 2374   2374                                                 ca
# 3282   3282  Pel que fa a la part de l'assignatura de la Do...
# ...     ...                                                ...
# 7881     80                                                  -
# 7885     84                                               \r\n
# 7886     85                                               \r\n
# 7887     86                                  No he après res.
# 7888     87                                   POC PROFESSIONAL
#
#              TipusIncidencia   Idioma IdiomaSpacy IdiomaPyCld2
# 1230                     NaN      NaN         NaN          NaN
# 1231                      ca      NaN         NaN          NaN
# 2373   Comentari problemàtic      NaN         NaN          NaN
# 2374                      ca      NaN         NaN          NaN
# 3282  Comentari de professor      NaN         NaN          NaN
# ...                      ...      ...         ...          ...
# 7881                     NaN  UNKNOWN     UNKNOWN           un
# 7885                     NaN  UNKNOWN     UNKNOWN           un
# 7886                     NaN  UNKNOWN     UNKNOWN           un
# 7887                     NaN       fr          fr           fr
# 7888                     NaN       pl          pl           ie
#
# [65 rows x 6 columns]
# 65  rows

# %%
# Registro con idioma diferente agrupados por tipo de incidencia

data_dif = data[data["IdiomaSpacy"] != data["IdiomaPyCld2"]]
data_incid = data_dif[data_dif["TipusIncidencia"].notnull()]
data_group = data_incid[["TipusIncidencia","Comentari"]].groupby(["TipusIncidencia"]).count()
data_group
# Out:
#                                      Comentari
# TipusIncidencia
# Comentari de professor                       2
# Comentari excel·lent                         1
# Comentari ofensiu                            4
# Comentari problemàtic                        7
# Exclamacions o emoticones excessius          1
# No ha impartit classe a aquest grup         59
# ca                                           5

# %% [markdown]
# Nivel general de coincidencia:
# - Textos con igual idioma: 7.351 / 7855 = 93,58 %
# - Textos con idioma diferente: 504 registros. Candidatos a recuperarse.
#
# Revisión idioma catalán:
# - Los textos detectados ca (spacy) - en (pycld2) són en realidad en catalán (141 casos)
# - Los textos detectados ca (spacy) - es (pycld2) són en realidad en catalán (11 casos)
# - Los textos detectados ca (spacy) - xx (pycld2) són en realidad en catalán (31 casos)
# Conclusión: En general la detección de catalán de Spacy es correcta
#
# Revisión idioma castellano:
# - Los textos detectados es (spacy) - ca (pycld2) són en realidad en catalán (16 casos)
# - Los textos detectados es (spacy) - en (pycld2) són en realidad en castellano (19 casos)
# - Los textos detectados es (spacy) - xx (pycld2) són en realidad en castellano (13 casos)
# Conclusión: En geneal la detección del castellano en Spacy es correcta, salvo para el idioma catalán, que se podria mejorar mediante pycld2
#
# Revisión idioma inglés:
# - Los textos detectados en (spacy) - ca (pycld2) són en realidad en catalán (60 casos)
# - Los textos detectados en (spacy) - es (pycld2) són en realidad en castellano (8 casos)
# - Los textos detectados en (spacy) - xx (pycld2) són en realidad en catalán (25 casos)
# Conclusión: Para el castellano y el catalán la detección de pycld2 es mejor y en el caso de otras lenguas se debería hacer una asignación directa al catalán.
#
# Revisión otras lenguas (xx representa las lengua que no son ca, es, en):
# - Los textos detectados xx (spacy) - ca (pycld2) són en realidad en catalán (68 casos)
# - Los textos detectados xx (spacy) - es (pycld2) són en realidad en castellano (28 casos)
# - Los textos detectados xx (spacy) - en (pycld2) són en realidad en catalán (30 casos)
# - Los textos detectados xx (spacy) - xx (pycld2) són casi todos catalán y el resto castellano (55 casos)
#
# Conclusión: Para el castellano y el catalán la detección de pycld2 es mejor y en el caso de otras lenguas se debería hacer una asignación directa al catalán.
#
# Agrupación por tipos de incidencia:
# - De los 505 registro recuperables 69 son incidencias.
# - La mayoría de las incidencias (58 registros) son de tipo 'No ha impartido clase'.
# - En todo el conjunto de datos hay 440 incidencias, 37 de tipo 'No ha impartido clase'.

# %%
# Detection of language using Spacy and PyCld2 and convination of both results

def detect_language(comment):
    
    lang_spacy = nlp(comment)._.language["language"]
    isReliable, textBytesFound, details = cld2.detect(comment.encode('utf-8', 'replace'), 
                                                    isPlainText = True, bestEffort = True, returnVectors=False)
    lang_pycld2 = details[0][1]
    
    language = lang_spacy
    if (lang_spacy != "ca") & (lang_pycld2 == "ca"):
        language = "ca"

    if (lang_spacy != "ca") & (lang_spacy != "es") & (lang_pycld2 == "es"):
        language = "es"
        
    if (lang_spacy == "en") & (lang_pycld2 != "ca") & (lang_pycld2 != "es") & (lang_pycld2 != "en"):
        language = "ca"
        
    if (debug == 2):
        print (comment, ", ", lang_spacy, ", ", lang_pycld2, ", ", language)
        
    return lang_spacy, lang_pycld2, language

# %%
# Mix of languages detection

comments = ["Algunes classes eren més dinàmiques que altres.",
            "El primer dia de classe no es va presentar",
            "Es inacceptable que una professora exigeigi tant",
            "Sempre disposat a ajudar en el que necessitis.",
            "Esta asignatura es una de las más importantes",
            "Alguna pràctica podría estar millor explicada",
            "En los videos tutoriales no hablar tan deprisa.",
            "Materiales estupendos para disfrutar y aprender.",
            "It was a very interactive class and learning.",
            "Criteris poc clars.",
            "Un buen profesional",
            "No l'hem tingut",
            "Assignatura molt interessant!",
            "ME HA GUSTADO MUCHO LA PROFESORA, SOBRE TODO",
            "BUEN PROFESOR...HA DESPERTADO INTERÉS EN LA ASIGNATURA.",
            "bona professora, propera i motivadora 	"]

for comment in comments:
    lang_spacy, lang_pycld2, language = detect_language(comment)
        
    print (comment, ", ", lang_spacy, ", ", lang_pycld2, ", ", language)
# Out:
# Algunes classes eren més dinàmiques que altres. ,  ca ,  ca ,  ca
# El primer dia de classe no es va presentar ,  ca ,  es ,  ca
# Es inacceptable que una professora exigeigi tant ,  ca ,  en ,  ca
# Sempre disposat a ajudar en el que necessitis. ,  ca ,  pt ,  ca
# Esta asignatura es una de las más importantes ,  es ,  es ,  es
# Alguna pràctica podría estar millor explicada ,  es ,  ca ,  ca
# En los videos tutoriales no hablar tan deprisa. ,  es ,  en ,  es
# Materiales estupendos para disfrutar y aprender. ,  es ,  id ,  es
# It was a very interactive class and learning. ,  en ,  en ,  en
# Criteris poc clars. ,  en ,  ca ,  ca
# Un buen profesional ,  en ,  es ,  es
# No l'hem tingut ,  en ,  tk ,  ca
# Assignatura molt interessant! ,  it ,  ca ,  ca
# ME HA GUSTADO MUCHO LA PROFESORA, SOBRE TODO ,  pt ,  es ,  es
# BUEN PROFESOR...HA DESPERTADO INTERÉS EN LA ASIGNATURA. ,  de ,  en ,  de
# bona professora, propera i motivadora 	 ,  it ,  fy ,  it
